# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot 
data = pd.read_csv(r"C:\Users\shrouk\Desktop\creditcard.csv")
##data exploration
print(data.head(5))
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(data.describe(include='all'))
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
print(data.duplicated().sum())
# Out:
# 1081

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
temp = data.drop(columns=['Time', 'Amount', 'Class'], axis=1)

# create dist plots
fig, ax = plot.subplots(ncols=4, nrows=7, figsize=(20, 50))
index = 0
ax = ax.flatten()

for col in temp.columns:
    sns.distplot(temp[col], ax=ax[index])
    index += 1
plot.tight_layout(pad=0.5, w_pad=0.5, h_pad=5)
# Out:
# C:\Users\shrouk\AppData\Local\Temp\ipykernel_20228\2216890558.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(temp[col], ax=ax[index])
# C:\Users\shrouk\AppData\Local\Temp\ipykernel_20228\2216890558.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(data['Time'])
# Out:
# C:\Users\shrouk\AppData\Local\Temp\ipykernel_20228\3557549204.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Time'])
# <Axes: xlabel='Time', ylabel='Density'>

# %%
corr = data.corr()
plot.figure(figsize=(30,40))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
data['Class'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions
#Number of Fraudulent Transactions = 492
legit = data[data.Class == 0]
fraud = data[data.Class == 1]
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit_sample = legit.sample(n=492)
new_dataset = pd.concat([legit_sample, fraud], axis=0)
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 62877    50462.0  0.811772 -0.309384  0.357915  1.514103 -0.504606 -0.374050
# 277632  167763.0  2.096650  0.606037 -2.727587  1.231220  1.541355 -0.653995
# 191358  129219.0 -4.124199 -2.544740 -0.496238 -0.959523 -3.672765  1.561312
# 4446      3770.0  1.149370 -0.554755  0.713768 -0.588592 -0.358713  0.877315
# 16426    27792.0 -0.572889  0.601674  1.570710 -1.057330  0.145150 -0.466727
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 62877   0.318480 -0.098172 -0.082459  ...  0.048452 -0.067388 -0.240578
# 277632  0.885080 -0.429114 -0.177081  ...  0.046301  0.376142 -0.165783
# 191358  3.632208 -1.939120  1.682814  ... -0.114122  0.587594  1.435906
# 4446   -0.888694  0.258944  0.366104  ... -0.081205  0.012695  0.283840
# 16426   0.565384  0.137487 -0.573796  ...  0.092978  0.166437 -0.039993
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_dataset['Class'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
new_dataset=new_dataset.round(2)
print(new_dataset.head(5))
# Out:
#             Time    V1    V2    V3    V4    V5    V6    V7    V8    V9  ...  \
# 62877    50462.0  0.81 -0.31  0.36  1.51 -0.50 -0.37  0.32 -0.10 -0.08  ...
# 277632  167763.0  2.10  0.61 -2.73  1.23  1.54 -0.65  0.89 -0.43 -0.18  ...
# 191358  129219.0 -4.12 -2.54 -0.50 -0.96 -3.67  1.56  3.63 -1.94  1.68  ...
# 4446      3770.0  1.15 -0.55  0.71 -0.59 -0.36  0.88 -0.89  0.26  0.37  ...
# 16426    27792.0 -0.57  0.60  1.57 -1.06  0.15 -0.47  0.57  0.14 -0.57  ...
#
#          V21   V22   V23   V24   V25   V26   V27   V28  Amount  Class
# 62877   0.05 -0.07 -0.24  0.57  0.63 -0.39 -0.01  0.04  183.90      0
# 277632  0.05  0.38 -0.17 -0.03  0.75 -0.38 -0.01 -0.04    9.99      0
# 191358 -0.11  0.59  1.44  0.07 -0.24  0.57  0.09  1.15  822.99      0
# 4446   -0.08  0.01  0.28 -0.69 -0.14 -0.42  0.05  0.01   35.39      0
# 16426   0.09  0.17 -0.04  0.27 -0.51  0.74  0.03  0.11    8.00      0
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
x= new_dataset.drop(['Class'], axis=1)
y=new_dataset.Class

# %%
print(x.shape)
print(y.shape)
# Out:
# (984, 30)
# (984,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaler = sc.fit_transform(x)
x_scaler[-1]
# Out:
# array([ 1.72433896,  0.78658948, -0.4552775 ,  0.14807114, -0.56604962,
#         0.64596998,  0.30883522,  0.50978759, -0.06630142,  0.8187715 ,
#         0.4353586 , -0.50958056,  0.83625706,  0.43091084,  0.32581972,
#        -0.79303814,  0.73793436,  0.71235873,  0.96999449,  0.19255246,
#        -0.19713838, -0.18290126, -0.25013667, -0.05414512, -0.73358653,
#         0.43663755, -0.63397787, -0.08134131, -0.14529528, -0.27604369])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# training
model.fit(x_train, y_train)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       150
#            1       0.97      0.88      0.92       146
#
#     accuracy                           0.93       296
#    macro avg       0.93      0.93      0.93       296
# weighted avg       0.93      0.93      0.93       296
#
# F1 Score: 0.9247311827956989

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
# training
model.fit(x_train, y_train)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       150
#            1       0.99      0.90      0.94       146
#
#     accuracy                           0.95       296
#    macro avg       0.95      0.95      0.95       296
# weighted avg       0.95      0.95      0.95       296
#
# F1 Score: 0.9424460431654675

# %%
#implement GNB Classifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
nv=GaussianNB()
nv.fit(x_train,y_train)
predict=nv.predict(x_test)
accuracy_score(y_test,predict)
# Out:
# 0.8682432432432432
